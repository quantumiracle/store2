# %% [markdown]
# ## Random Object, 2-head Training
# ### Train on random env

# %% [markdown]
# 8.22 new, fix bug of deformation parameters
#
# Size: training set   testing set    random testing set
# all pins 2246  201  303
# threshold 2246  201  303
# weighted average
#
# Mean Square Error: training set
#                 obj                rotation              position            total
# all pins 0.07248977343175954  0.08125057665554984  0.0096765996621922  0.060071781198289056
# threshold  0.01742373847950653  0.024409784768199126  0.0044301460002592885  0.016795107717954443
# weighted average 0.12436873327829794  0.1476181125641485  0.03554573394070377  0.11088150067609336
# learned (dim 10) 0.0470  0.0759  0.0094  0.0485
# learned (dim 20) 0.0556  0.0913  0.0096  0.0575
#
#
# Mean Square Error: testing set
#                 obj                rotation              position            total
# all pins 0.05786661889542961  0.07065042551602177  0.011915773489348545  0.05117283502663139
# threshold  0.017427735865643796  0.023921371495825343  0.0059278749978916275  0.016987884010023838
# weighted average 0.09005502178005628  0.12131971259754185  0.02747928188868792  0.08613534586377128
#
# Mean Square Error: random testing set (0.2)
#                 obj                rotation              position            total
#
# all pins from random0.2  0.1525  0.1080  0.0111  0.1005
# thre from random0.2 0.0450  0.0328  0.0051  0.0304
# wa from random0.2 0.1360  0.2123  0.0483  0.1427
# learned from random0.2 (dim 20) 0.0571  0.0903  0.0092  0.0576
#
# Mean Square Error: random testing set (0.5)
#                 obj                rotation              position            total
#
# all pins from random0.2  0.1461  0.1387  0.0261  0.1133
# thre from random0.2   0.1349  0.2430  0.0558  0.1557
# wa from random0.2 0.1282  0.3129  0.1211  0.1957
# learned from random0.2 (dim 20) 0.1090  0.2422  0.0293  0.1390

# %%
# plot object prediction
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['Pins Position', 'Threshold', \
          'Weighted Average', 'Learned']
random_env2=[0.1461,0.1349, 0.3129, 0.1090]
random_env = [0.1525, 0.0450, 0.1360, 0.0571]

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots(figsize=(6,5))

# rects1 = ax.bar(x - width, fixed_env, width, label='Fixed Dynamics')
rects2 = ax.bar(x , random_env2, width, label='Random Dynamics (0.2)')
rects3 = ax.bar(x + width, random_env, width, label='Random Dynamics (0.5)')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mean Square Error of Prediction')
ax.set_title('Performance Test (Object Index)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')



autolabel(rects2)
autolabel(rects3)

fig.tight_layout()
plt.savefig('test_obj2.png')
plt.show()

# %%
# plot rotation prediction
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['Pins Position', 'Threshold', \
          'Weighted Average', 'Learned']

random_env2=[0.1080, 0.0328, 0.2123, 0.0903 ]
random_env = [0.1387, 0.2430, 0.3129, 0.2422
]

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots(figsize=(6,5))

rects2 = ax.bar(x , random_env2, width, label='Random Dynamics (0.2)')
rects3 = ax.bar(x + width, random_env, width, label='Random Dynamics (0.5)')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mean Square Error of Prediction')
ax.set_title('Performance Test (Rotation Angles)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')



autolabel(rects2)
autolabel(rects3)
fig.tight_layout()
plt.savefig('test_rotat2.png')
plt.show()

# %%
# plot position prediction
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['Pins Position', 'Threshold', \
          'Weighted Average', 'Learned']

random_env2=[0.0111, 0.0051, 0.0483, 0.0092]
random_env = [0.0261, 0.0558, 0.1211, 0.0293
]

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots(figsize=(6,5))

rects2 = ax.bar(x , random_env2, width, label='Random Dynamics (0.2)')
rects3 = ax.bar(x + width, random_env, width, label='Random Dynamics (0.5)')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mean Square Error of Prediction')
ax.set_title('Performance Test (Collision Position)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')



autolabel(rects2)
autolabel(rects3)

fig.tight_layout()
plt.savefig('test_pos2.png')
plt.show()

# %%
# plot total prediction loss
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['Pins Position', 'Threshold', \
          'Weighted Average', 'Learned']

random_env2 = [0.1005, 0.0304, 0.1427, 0.0576
]
random_env = [0.1133, 0.1557, 0.1957, 0.1390
]


x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots(figsize=(6,5))

rects2 = ax.bar(x , random_env2, width, label='Random Dynamics (0.2)')
rects3 = ax.bar(x + width, random_env, width, label='Random Dynamics (0.5)')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Mean Square Error of Prediction')
ax.set_title('Performance Test (Total Error)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects2)
autolabel(rects3)

fig.tight_layout()
plt.savefig('test_total2.png')
plt.show()
